# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
melb_data = pd.read_csv("melb_data.csv")

# %%
melb_data.describe()
# Out:
#          Unnamed: 0         Rooms         Price      Distance      Postcode  \
# count  18396.000000  18396.000000  1.839600e+04  18395.000000  18395.000000
# mean   11826.787073      2.935040  1.056697e+06     10.389986   3107.140147
# std     6800.710448      0.958202  6.419217e+05      6.009050     95.000995
# min        1.000000      1.000000  8.500000e+04      0.000000   3000.000000
# 25%     5936.750000      2.000000  6.330000e+05      6.300000   3046.000000
# 50%    11820.500000      3.000000  8.800000e+05      9.700000   3085.000000
# 75%    17734.250000      3.000000  1.302000e+06     13.300000   3149.000000
# max    23546.000000     12.000000  9.000000e+06     48.100000   3978.000000
#
#            Bedroom2      Bathroom           Car       Landsize  BuildingArea  \
# count  14927.000000  14925.000000  14820.000000   13603.000000   7762.000000
# mean       2.913043      1.538492      1.615520     558.116371    151.220219
# ...

# %%
melb_data.head(10)
# Out:
#    Unnamed: 0      Suburb           Address  Rooms Type      Price Method  \
# 0           1  Abbotsford      85 Turner St      2    h  1480000.0      S
# 1           2  Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2           4  Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3           5  Abbotsford  40 Federation La      3    h   850000.0     PI
# 4           6  Abbotsford       55a Park St      4    h  1600000.0     VB
# 5          10  Abbotsford    129 Charles St      2    h   941000.0      S
# 6          11  Abbotsford      124 Yarra St      3    h  1876000.0      S
# 7          14  Abbotsford     98 Charles St      2    h  1636000.0      S
# 8          15  Abbotsford  217 Langridge St      3    h  1000000.0      S
# 9          16  Abbotsford   18a Mollison St      2    t   745000.0      S
#
#   SellerG       Date  Distance      ...        Bathroom  Car  Landsize  \
# 0  Biggin  3/12/2016       2.5      ...             1.0  1.0     202.0
# ...

# %%
melb_data.columns
# Out:
# Index(['Unnamed: 0', 'Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method',
#        'SellerG', 'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom',
#        'Car', 'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea',
#        'Lattitude', 'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
Y = melb_data['Price']

# %%
Y
# Out:
# 0        1480000.0
# 1        1035000.0
# 2        1465000.0
# 3         850000.0
# 4        1600000.0
# 5         941000.0
# 6        1876000.0
# 7        1636000.0
# 8        1000000.0
# 9         745000.0
# 10        300000.0
# 11       1097000.0
# 12        542000.0
# 13        760000.0
# 14        481000.0
# 15        700000.0
# 16       1350000.0
# 17        750000.0
# 18       1985000.0
# 19        500000.0
# 20       1172500.0
# 21        441000.0
# 22       1310000.0
# 23       1200000.0
# 24        847000.0
# 25       1176500.0
# 26        955000.0
# 27        890000.0
# 28       1330000.0
# 29        900000.0
#            ...
# 18366     720000.0
# 18367     631000.0
# 18368     523000.0
# 18369     530000.0
# 18370     540000.0
# 18371     290000.0
# 18372    1263500.0
# 18373     931000.0
# 18374    1295000.0
# 18375    1250000.0
# 18376    1316000.0
# 18377     951000.0
# 18378    1323000.0
# 18379     970000.0
# 18380    1330000.0
# 18381     590000.0
# ...

# %%
melb_data.dtypes
# Out:
# Unnamed: 0         int64
# Suburb            object
# Address           object
# Rooms              int64
# Type              object
# Price            float64
# Method            object
# SellerG           object
# Date              object
# Distance         float64
# Postcode         float64
# Bedroom2         float64
# Bathroom         float64
# Car              float64
# Landsize         float64
# BuildingArea     float64
# YearBuilt        float64
# CouncilArea       object
# Lattitude        float64
# Longtitude       float64
# Regionname        object
# Propertycount    float64
# dtype: object

# %%
X = melb_data.select_dtypes(exclude=["object"]).dropna(axis=0)

# %%
from sklearn.model_selection import train_test_split

# %%
X.shape
# Out:
# (6830, 14)

# %%
Y.shape
# Out:
# (18396,)

# %%
# %config IPCompleter.greedy=True

# %%
melb_data.Price
# Out:
# 0        1480000.0
# 1        1035000.0
# 2        1465000.0
# 3         850000.0
# 4        1600000.0
# 5         941000.0
# 6        1876000.0
# 7        1636000.0
# 8        1000000.0
# 9         745000.0
# 10        300000.0
# 11       1097000.0
# 12        542000.0
# 13        760000.0
# 14        481000.0
# 15        700000.0
# 16       1350000.0
# 17        750000.0
# 18       1985000.0
# 19        500000.0
# 20       1172500.0
# 21        441000.0
# 22       1310000.0
# 23       1200000.0
# 24        847000.0
# 25       1176500.0
# 26        955000.0
# 27        890000.0
# 28       1330000.0
# 29        900000.0
#            ...
# 18366     720000.0
# 18367     631000.0
# 18368     523000.0
# 18369     530000.0
# 18370     540000.0
# 18371     290000.0
# 18372    1263500.0
# 18373     931000.0
# 18374    1295000.0
# 18375    1250000.0
# 18376    1316000.0
# 18377     951000.0
# 18378    1323000.0
# 18379     970000.0
# 18380    1330000.0
# 18381     590000.0
# ...

# %%
melb_data.Address
# Out:
# 0               85 Turner St
# 1            25 Bloomburg St
# 2               5 Charles St
# 3           40 Federation La
# 4                55a Park St
# 5             129 Charles St
# 6               124 Yarra St
# 7              98 Charles St
# 8           217 Langridge St
# 9            18a Mollison St
# 10        6/241 Nicholson St
# 11             10 Valiant St
# 12       403/609 Victoria St
# 13         25/84 Trenerry Cr
# 14         106/119 Turner St
# 15        411/8 Grosvenor St
# 16           40 Nicholson St
# 17       123/56 Nicholson St
# 18                22 Park St
# 19         13/84 Trenerry Cr
# 20             45 William St
# 21        7/20 Abbotsford St
# 22             16 William St
# 23               42 Henry St
# 24          250 Langridge St
# 25               78 Yarra St
# 26          196 Nicholson St
# 27             42 Valiant St
# 28           3/72 Charles St
# 29        13/11 Nicholson St
#                 ...
# 18366     21/1059 Malvern Rd
# ...

# %%
X
# Out:
#        Unnamed: 0  Rooms      Price  Distance  Postcode  Bedroom2  Bathroom  \
# 1               2      2  1035000.0       2.5    3067.0       2.0       1.0
# 2               4      3  1465000.0       2.5    3067.0       3.0       2.0
# 4               6      4  1600000.0       2.5    3067.0       3.0       1.0
# 6              11      3  1876000.0       2.5    3067.0       4.0       2.0
# 7              14      2  1636000.0       2.5    3067.0       2.0       1.0
# 11             18      2  1097000.0       2.5    3067.0       3.0       1.0
# 16             24      3  1350000.0       2.5    3067.0       3.0       2.0
# 17             25      2   750000.0       2.5    3067.0       2.0       2.0
# 22             30      2  1310000.0       2.5    3067.0       2.0       1.0
# 23             32      3  1200000.0       2.5    3067.0       3.0       2.0
# 25             35      3  1176500.0       2.5    3067.0       2.0       1.0
# ...

# %%
melb_data.shape
# Out:
# (18396, 22)

# %%
X.shape
# Out:
# (6830, 14)

# %%
melb_data.Price.shape
# Out:
# (18396,)

# %%
X = melb_data.select_dtypes(exclude=["object"])

# %%
X.shape
# Out:
# (18396, 14)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

# %%
X.columns
# Out:
# Index(['Unnamed: 0', 'Rooms', 'Price', 'Distance', 'Postcode', 'Bedroom2',
#        'Bathroom', 'Car', 'Landsize', 'BuildingArea', 'YearBuilt', 'Lattitude',
#        'Longtitude', 'Propertycount'],
#       dtype='object')

# %%
X = X.drop(["Price"], axis=1)

# %%
X.columns
# Out:
# Index(['Unnamed: 0', 'Rooms', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom',
#        'Car', 'Landsize', 'BuildingArea', 'YearBuilt', 'Lattitude',
#        'Longtitude', 'Propertycount'],
#       dtype='object')

# %%
X.shape
# Out:
# (18396, 13)

# %%
X.dtypes
# Out:
# Unnamed: 0         int64
# Rooms              int64
# Distance         float64
# Postcode         float64
# Bedroom2         float64
# Bathroom         float64
# Car              float64
# Landsize         float64
# BuildingArea     float64
# YearBuilt        float64
# Lattitude        float64
# Longtitude       float64
# Propertycount    float64
# dtype: object

# %%
X_train, X_test, y_train, y_test = train_test_split(X, melb_data.Price, random_state=0)

# %%
X_train.shape
# Out:
# (13797, 13)

# %%
model = RandomForestRegressor(n_estimators=10, max_depth=40)

# %%
X_train.isnull().sum()
# Out:
# Unnamed: 0          0
# Rooms               0
# Distance            1
# Postcode            1
# Bedroom2         2594
# Bathroom         2595
# Car              2671
# Landsize         3576
# BuildingArea     7986
# YearBuilt        7064
# Lattitude        2499
# Longtitude       2499
# Propertycount       1
# dtype: int64

# %%
X = pd.get_dummies(melb_data.dropna(axis=0))

# %%
X.isnull().sum()
# Out:
# Unnamed: 0                               0
# Rooms                                    0
# Price                                    0
# Distance                                 0
# Postcode                                 0
# Bedroom2                                 0
# Bathroom                                 0
# Car                                      0
# Landsize                                 0
# BuildingArea                             0
# YearBuilt                                0
# Lattitude                                0
# Longtitude                               0
# Propertycount                            0
# Suburb_Abbotsford                        0
# Suburb_Aberfeldie                        0
# Suburb_Airport West                      0
# Suburb_Albanvale                         0
# Suburb_Albert Park                       0
# Suburb_Albion                            0
# Suburb_Alphington                        0
# Suburb_Altona                            0
# ...

# %%
X.shape
# Out:
# (6196, 6719)

# %%
y = X.Price

# %%
y
# Out:
# 1        1035000.0
# 2        1465000.0
# 4        1600000.0
# 6        1876000.0
# 7        1636000.0
# 11       1097000.0
# 16       1350000.0
# 17        750000.0
# 22       1310000.0
# 23       1200000.0
# 25       1176500.0
# 27        890000.0
# 28       1330000.0
# 31        500000.0
# 32       1100000.0
# 33       1315000.0
# 37       1447500.0
# 39       1135000.0
# 44       1290000.0
# 45        470000.0
# 46       1180000.0
# 47       1195000.0
# 48       1012500.0
# 50       1030000.0
# 52        840000.0
# 53        730000.0
# 54        770000.0
# 55        603000.0
# 56        700000.0
# 57        600000.0
#            ...
# 15333     880000.0
# 15335     945000.0
# 15336     730000.0
# 15338     980000.0
# 15345     570000.0
# 15350     600000.0
# 15351     360000.0
# 15353     475000.0
# 15354     495000.0
# 15356     695000.0
# 15357     760000.0
# 15358     583500.0
# 15360     585000.0
# 15363    1245000.0
# 15364    2000000.0
# 15366     407000.0
# ...

# %%
X.columns
# Out:
# Index(['Unnamed: 0', 'Rooms', 'Price', 'Distance', 'Postcode', 'Bedroom2',
#        'Bathroom', 'Car', 'Landsize', 'BuildingArea',
#        ...
#        'CouncilArea_Yarra', 'CouncilArea_Yarra Ranges',
#        'Regionname_Eastern Metropolitan', 'Regionname_Eastern Victoria',
#        'Regionname_Northern Metropolitan', 'Regionname_Northern Victoria',
#        'Regionname_South-Eastern Metropolitan',
#        'Regionname_Southern Metropolitan', 'Regionname_Western Metropolitan',
#        'Regionname_Western Victoria'],
#       dtype='object', length=6719)

# %%
X = X.drop(["Price"], axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %%
model.fit(X_train, y_train).score(X_test, y_test)
# Out:
# 0.7278687492281406

# %%
from PIL import Image
import numpy as np
i = Image.open("download.jpeg")
a  = np.asarray(i)
a.shape
# Out:
# (159, 318, 3)

# %%
i = Image.open("download (1) 16-33-01-694.jpeg")
a = np.asarray(i)
a.shape
# Out:
# (40, 40, 3)

# %%
i = Image.open("18813218.jpeg")
a = np.asarray(i)
a.shape
# Out:
# (180, 240, 3)

# %%
new = i.convert('1')
new.save("djfaldf.jpeg")

# %%
a_new = np.asarray(new)

# %%
a_new.shape
# Out:
# (180, 240)

# %%
old = i.convert('RGB')

# %%
old.save("od.jpeg")

# %%
old_arr = np.asarray(old)
old_arr.shape
# Out:
# (180, 240, 3)

# %%
old.save("od.jpeg")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-07b8bed21423> in <module>()
# ----> 1 old.save("od.jpeg")
#
# NameError: name 'old' is not defined
