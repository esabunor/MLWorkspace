# %%
import nltk

# %%
# previous nltk.download()

# %%
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
text1
# Out:
# <Text: Moby Dick by Herman Melville 1851>

# %%
text1.concordance('monstrous')
# Out:
# Displaying 11 of 11 matches:
# ong the former , one was of a most monstrous size . ... This came towards us ,
# ON OF THE PSALMS . " Touching that monstrous bulk of the whale or ork we have r
# ll over with a heathenish array of monstrous clubs and spears . Some were thick
# d as you gazed , and wondered what monstrous cannibal and savage could ever hav
# that has survived the flood ; most monstrous and most mountainous ! That Himmal
# they might scout at Moby Dick as a monstrous fable , or still worse and more de
# th of Radney .'" CHAPTER 55 Of the Monstrous Pictures of Whales . I shall ere l
# ing Scenes . In connexion with the monstrous pictures of whales , I am strongly
# ere to enter upon those still more monstrous stories of them which are to be fo
# ght have been rummaged out of this monstrous cabinet there is no telling . But
# of Whale - Bones ; for Whales of a monstrous size are oftentimes cast up dead u

# %%
text2
# Out:
# <Text: Sense and Sensibility by Jane Austen 1811>

# %%
text2.concordance('monstrous')
# Out:
# Displaying 11 of 11 matches:
# . " Now , Palmer , you shall see a monstrous pretty girl ." He immediately went
# your sister is to marry him . I am monstrous glad of it , for then I shall have
# ou may tell your sister . She is a monstrous lucky girl to get him , upon my ho
# k how you will like them . Lucy is monstrous pretty , and so good humoured and
#  Jennings , " I am sure I shall be monstrous glad of Miss Marianne ' s company
#  usual noisy cheerfulness , " I am monstrous glad to see you -- sorry I could n
# t however , as it turns out , I am monstrous glad there was never any thing in
# so scornfully ! for they say he is monstrous fond of her , as well he may . I s
# possible that she should ." " I am monstrous glad of it . Good gracious ! I hav
# thing of the kind . So then he was monstrous happy , and talked on some time ab
# e very genteel people . He makes a monstrous deal of money , and they keep thei

# %%
text2.similar('monstrous')
# Out:
# very so exceedingly heartily a as good great extremely remarkably
# sweet vast amazingly

# %%
text1.similar('monstrous')
# Out:
# true contemptible christian abundant few part mean careful puzzled
# mystifying passing curious loving wise doleful gamesome singular
# delightfully perilous fearless

# %%
# %config IPCompleter.greedy=True

# %%
text1.vocab()
# Out:
# FreqDist({'[': 3,
#           'Moby': 84,
#           'Dick': 84,
#           'by': 1137,
#           'Herman': 1,
#           'Melville': 1,
#           '1851': 3,
#           ']': 1,
#           'ETYMOLOGY': 1,
#           '.': 6862,
#           '(': 210,
#           'Supplied': 2,
#           'a': 4569,
#           'Late': 1,
#           'Consumptive': 1,
#           'Usher': 2,
#           'to': 4542,
#           'Grammar': 2,
#           'School': 1,
#           ')': 78,
#           'The': 612,
#           'pale': 18,
#           '--': 1070,
#           'threadbare': 1,
#           'in': 3916,
#           'coat': 28,
#           ',': 18713,
#           'heart': 90,
#           'body': 110,
#           'and': 6024,
#           'brain': 37,
#           ';': 4072,
#           'I': 2124,
#           'see': 253,
#           'him': 1058,
#           'now': 646,
#           'He': 230,
#           'was': 1632,
#           'ever': 203,
#           'dusting': 2,
#           'his': 2459,
# ...

# %%
text2.common_contexts(['monstrous', 'very'])
# Out:
# a_pretty am_glad a_lucky is_pretty be_glad

# %%
text1.similar('monstrous')
# Out:
# true contemptible christian abundant few part mean careful puzzled
# mystifying passing curious loving wise doleful gamesome singular
# delightfully perilous fearless

# %%
text1.common_contexts(['monstrous', 'true'])
# Out:
# the_pictures

# %%
text1.concordance('picture')
# Out:
# Displaying 19 of 19 matches:
# r hill - side blue . But though the picture lies thus tranced , and though this
# thing hovering in the centre of the picture over three blue , dim , perpendicul
#  yeast . A boggy , soggy , squitchy picture truly , enough to drive a nervous m
# hat one portentous something in the picture ' s midst . THAT once found out , a
#  I conversed upon the subject . The picture represents a Cape - Horner in a gre
# hat had achieved the ladder and the picture . Its panelled front was in the lik
# tediluvian Hindoo . It is Guido ' s picture of Perseus rescuing Andromeda from
#  is an outline purporting to be a " Picture of a Physeter or Spermaceti whale ,
#  not the captain had this veracious picture taken for the benefit of his marine
# se are not only incorrect , but the picture of the Mysticetus or Greenland whal
# , in which he gives what he calls a picture of the Sperm Whale . Before showing
# ...

# %%
text2
# Out:
# <Text: Sense and Sensibility by Jane Austen 1811>

# %%
text3.concordance('beginning')
# Out:
# Displaying 5 of 5 matches:
#                                    beginning God created the heaven and the ear
# y hunter before the LORD . And the beginning of his kingdom was Babel , and Ere
# ace where his tent had been at the beginning , between Bethel and Hai ; Unto th
# ere still ill favoured , as at the beginning . So I awoke . And I saw in my dre
#  my firstborn , my might , and the beginning of my strength , the excellency of

# %%
text4.dispersion_plot(['citizens', 'democracy'])

# %%
len(text4)
# Out:
# 145735

# %%
text4.dispersion_plot(['citizens', 'democracy', 'freedom', 'duties', 'America'])

# %%
text4.vocab()
# Out:
# FreqDist({'Fellow': 24,
#           '-': 280,
#           'Citizens': 7,
#           'of': 6970,
#           'the': 9281,
#           'Senate': 11,
#           'and': 4991,
#           'House': 8,
#           'Representatives': 5,
#           ':': 124,
#           'Among': 4,
#           'vicissitudes': 5,
#           'incident': 8,
#           'to': 4311,
#           'life': 133,
#           'no': 406,
#           'event': 16,
#           'could': 69,
#           'have': 994,
#           'filled': 6,
#           'me': 186,
#           'with': 886,
#           'greater': 52,
#           'anxieties': 3,
#           'than': 234,
#           'that': 1688,
#           'which': 1002,
#           'notification': 1,
#           'was': 268,
#           'transmitted': 3,
#           'by': 1036,
#           'your': 104,
#           'order': 64,
#           ',': 6840,
#           'received': 12,
#           'on': 496,
#           '14th': 1,
#           'day': 87,
#           'present': 85,
# ...

# %%
print(text3.generate(words=300))
# Out:
# None

# %%
len(sorted(set(text3)))
# Out:
# 2789

# %%
len(text3)
# Out:
# 44764

# %%
len(text3) / len(sorted(set(text3)))
# Out:
# 16.050197203298673

# %%
text5
# Out:
# <Text: Chat Corpus>

# %%
text5.count('lol')
# Out:
# 704

# %%
text5.count('haha')
# Out:
# 44

# %%
def lexical_diversity(text):
    return len(text) / len(sorted(set(text)))

def percentage(count, total):
    return 100 * count / total

# %%
lexical_diversity(text5)
# Out:
# 7.420046158918563

# %%
lexical_diversity(text3)
# Out:
# 16.050197203298673

# %%
percentage(text4.count('a'), len(text4))
# Out:
# 1.4643016433938312

# %%
FreqDist(text1).keys()
# Out:
# dict_keys(['[', 'Moby', 'Dick', 'by', 'Herman', 'Melville', '1851', ']', 'ETYMOLOGY', '.', '(', 'Supplied', 'a', 'Late', 'Consumptive', 'Usher', 'to', 'Grammar', 'School', ')', 'The', 'pale', '--', 'threadbare', 'in', 'coat', ',', 'heart', 'body', 'and', 'brain', ';', 'I', 'see', 'him', 'now', 'He', 'was', 'ever', 'dusting', 'his', 'old', 'lexicons', 'grammars', 'with', 'queer', 'handkerchief', 'mockingly', 'embellished', 'all', 'the', 'gay', 'flags', 'of', 'known', 'nations', 'world', 'loved', 'dust', 'it', 'somehow', 'mildly', 'reminded', 'mortality', '"', 'While', 'you', 'take', 'hand', 'school', 'others', 'teach', 'them', 'what', 'name', 'whale', '-', 'fish', 'is', 'be', 'called', 'our', 'tongue', 'leaving', 'out', 'through', 'ignorance', 'letter', 'H', 'which', 'almost', 'alone', 'maketh', 'signification', 'word', 'deliver', 'that', 'not', 'true', '."', 'HACKLUYT', 'WHALE', '...', 'Sw', 'Dan', 'HVAL', 'This', 'animal', 'named', 'from', 'roundness', 'or', 'rolling', 'for', 'HVALT
# ...

# %%
FreqDist(text1).plot(50, cumulative=True)

# %%
# %matplotlib notebook

# %%
FreqDist(text1).plot(50, cumulative=True)
# Out:
# <div id='fe01faa8-c658-460a-8688-84c76e5422d4'></div>

# %%
len(text1)
# Out:
# 260819

# %%
FreqDist(text1).hapaxes()
# Out:
# ['Herman',
#  'Melville',
#  ']',
#  'ETYMOLOGY',
#  'Late',
#  'Consumptive',
#  'School',
#  'threadbare',
#  'lexicons',
#  'mockingly',
#  'flags',
#  'mortality',
#  'signification',
#  'HACKLUYT',
#  'Sw',
#  'HVAL',
#  'roundness',
#  'Dut',
#  'Ger',
#  'WALLEN',
#  'WALW',
#  'IAN',
#  'RICHARDSON',
#  'KETOS',
#  'GREEK',
#  'CETUS',
#  'LATIN',
#  'WHOEL',
#  'ANGLO',
#  'SAXON',
#  'WAL',
#  'HWAL',
#  'SWEDISH',
#  'ICELANDIC',
#  'BALEINE',
#  'BALLENA',
#  'FEGEE',
#  'ERROMANGOAN',
#  'Librarian',
#  'painstaking',
#  'burrower',
#  'grub',
#  'Vaticans',
#  'stalls',
#  'higgledy',
#  'piggledy',
#  'gospel',
#  'promiscuously',
#  'commentator',
#  'belongest',
#  'sallow',
#  'Pale',
#  'Sherry',
#  'loves',
#  'bluntly',
#  'Subs',
#  'thankless',
#  'Hampton',
#  'Court',
#  'hie',
#  'refugees',
#  'pampered',
#  'Michael',
#  'Raphael',
#  'unsplinterable',
#  'GENESIS',
#  'JOB',
#  'JONAH',
#  'punish',
#  'ISAIAH',
#  'soever',
#  'cometh',
# ...

# %%
text1.collocations()
# Out:
# Sperm Whale; Moby Dick; White Whale; old man; Captain Ahab; sperm
# whale; Right Whale; Captain Peleg; New Bedford; Cape Horn; cried Ahab;
# years ago; lower jaw; never mind; Father Mapple; cried Stubb; chief
# mate; white whale; ivory leg; one hand

# %%
text5.collocations()
# Out:
# wanna chat; PART JOIN; MODE #14-19teens; JOIN PART; PART PART;
# cute.-ass MP3; MP3 player; JOIN JOIN; times .. .; ACTION watches; guys
# wanna; song lasts; last night; ACTION sits; -...)...- S.M.R.; Lime
# Player; Player 12%; dont know; lez gurls; long time

# %%
text4.collocations()
# Out:
# United States; fellow citizens; four years; years ago; Federal
# Government; General Government; American people; Vice President; Old
# World; Almighty God; Fellow citizens; Chief Magistrate; Chief Justice;
# God bless; every citizen; Indian tribes; public debt; one another;
# foreign nations; political parties

# %%
from nltk.corpus import PlaintextCorpusReader

# %%
corpus_root = '/Users/tegaesabunor/Downloads'
wordlists = PlaintextCorpusReader(corpus_root, ['_chat.txt', '_chat2.txt', '_chat3.txt'])

# %%
wordlists.fileids()
# Out:
# ['_chat.txt', '_chat2.txt', '_chat3.txt']

# %%
wordlists.words()
# Out:
# ['[', '31', '/', '7', '/', '17', ',', '4', ':', '03', ...]

# %%
wordlists.sents('_chat.txt')
# Out:
# [['[', '31', '/', '7', '/', '17', ',', '4', ':', '03', ':', '15', 'am', ']', 'Lizzy', 'Okah', ':', '\u200e', 'Messages', 'to', 'this', 'chat', 'and', 'calls', 'are', 'now', 'secured', 'with', 'end', '-', 'to', '-', 'end', 'encryption', '.'], ['[', '14', '/', '8', '/', '17', ',', '3', ':', '33', ':', '54', 'pm', ']', 'Tega', 'Esabunor', ':', 'I', 'keep', 'dialling', 'you', 'by', 'accident', ',', 'soon', 'I', "'", 'll', 'do', 'on', 'purpose', 'just', 'tell', 'me', 'when', '.'], ...]

# %%
print(bigrams(wordlists.sents('_chat.txt')[0]))
# Out:
# <generator object bigrams at 0x122b685c8>

# %%
import nltk

# %%
print(list(nltk.bigrams(wordlists.sents('_chat.txt')[0])))
# Out:
# [('[', '31'), ('31', '/'), ('/', '7'), ('7', '/'), ('/', '17'), ('17', ','), (',', '4'), ('4', ':'), (':', '03'), ('03', ':'), (':', '15'), ('15', 'am'), ('am', ']'), (']', 'Lizzy'), ('Lizzy', 'Okah'), ('Okah', ':'), (':', '\u200e'), ('\u200e', 'Messages'), ('Messages', 'to'), ('to', 'this'), ('this', 'chat'), ('chat', 'and'), ('and', 'calls'), ('calls', 'are'), ('are', 'now'), ('now', 'secured'), ('secured', 'with'), ('with', 'end'), ('end', '-'), ('-', 'to'), ('to', '-'), ('-', 'end'), ('end', 'encryption'), ('encryption', '.')]

# %%
FreqDist(wordlists.sents('_chat.txt')[-1])
# Out:
# FreqDist({',': 2,
#           '/': 4,
#           '1': 2,
#           '12': 2,
#           '18': 2,
#           '22': 1,
#           '36': 2,
#           '41': 1,
#           '9': 2,
#           ':': 6,
#           'Bye': 1,
#           'Esabunor': 1,
#           'Lizzy': 1,
#           'Okah': 1,
#           'Tega': 1,
#           '[': 2,
#           ']': 2,
#           'am': 2,
#           'bye': 1,
#           'see': 1,
#           'ya': 1})

# %%
FreqDist(wordlists.sents('_chat.txt')[-1])['bye']
# Out:
# 1

# %%
def unusualwords(text):
    text_vocab = set(w.lower() for w in text if w.isalpha())
    english_words = set(w.lower() for w in nltk.corpus.words.words())
    unusual = text_vocab.difference(english_words)
    return sorted(unusual)

# %%
unusualwords(nltk.corpus.nps_chat.words())
# Out:
# ['aaaaaaaaaaaaaaaaa',
#  'aaahhhh',
#  'abortions',
#  'abou',
#  'abourted',
#  'abs',
#  'ack',
#  'acros',
#  'actualy',
#  'adams',
#  'adds',
#  'adduser',
#  'adjusts',
#  'adoted',
#  'adreniline',
#  'ads',
#  'adults',
#  'afe',
#  'affairs',
#  'affari',
#  'affects',
#  'afk',
#  'agaibn',
#  'ages',
#  'aggravated',
#  'agurlwithbigguns',
#  'ahah',
#  'ahahah',
#  'ahahh',
#  'ahahha',
#  'ahh',
#  'ahhah',
#  'ahhahahaha',
#  'ahhh',
#  'ahhhh',
#  'ahhhhhh',
#  'ahhhhhhhhhhhhhh',
#  'aiiiiiiiiiiiiiiiiiiiiiiii',
#  'aiken',
#  'aime',
#  'akdt',
#  'akon',
#  'akron',
#  'akst',
#  'aligator',
#  'allergies',
#  'allo',
#  'allowed',
#  'aloha',
#  'alohaaa',
#  'alohas',
#  'alot',
#  'alotta',
#  'alternatives',
#  'alterz',
#  'alwys',
#  'alzheimers',
#  'amazingness',
#  'americans',
#  'anithing',
#  'ans',
#  'answering',
#  'answers',
#  'antidepressants',
#  'anygirl',
#  'anymore',
#  'anythin',
#  'anytime',
#  'anyyyyyyyyyyyyyyyyy',
#  'aok',
# ...

# %%
unusualwords(wordlists.words('_chat.txt'))
# Out:
# ['abi',
#  'accommodationrooms',
#  'accoutrement',
#  'accusations',
#  'acoutre',
#  'adadevoh',
#  'ademola',
#  'ages',
#  'ahan',
#  'ahh',
#  'aiit',
#  'ain',
#  'aliyu',
#  'amazeballs',
#  'amina',
#  'announced',
#  'anytime',
#  'applications',
#  'applies',
#  'asap',
#  'asked',
#  'asking',
#  'aspx',
#  'aww',
#  'awww',
#  'awwwwww',
#  'badbele',
#  'bb',
#  'bebe',
#  'bibia',
#  'bida',
#  'biobaku',
#  'bobrisky',
#  'breaak',
#  'bro',
#  'brothers',
#  'btw',
#  'bugs',
#  'calls',
#  'cancelled',
#  'changed',
#  'chased',
#  'chats',
#  'chatted',
#  'choosey',
#  'clarifying',
#  'cleared',
#  'clicked',
#  'com',
#  'comments',
#  'cong',
#  'couldn',
#  'courses',
#  'cray',
#  'creams',
#  'decades',
#  'deductions',
#  'deleted',
#  'deleting',
#  'delivering',
#  'depends',
#  'destroyed',
#  'details',
#  'dialling',
#  'didn',
#  'discussing',
#  'dissappeared',
#  'distanced',
#  'distractions',
#  'doesn',
#  'dolapo',
#  'dominos',
#  'dp',
# ...

# %%
from nltk.corpus import wordnet as wn

# %%
wn.synsets('motorcar')
# Out:
# [Synset('car.n.01')]

# %%
wn.synsets('stupid')
# Out:
# [Synset('stupid.n.01'),
#  Synset('stupid.a.01'),
#  Synset('dazed.s.01'),
#  Synset('unintelligent.a.01')]

# %%
wn.synsets('car')
# Out:
# [Synset('car.n.01'),
#  Synset('car.n.02'),
#  Synset('car.n.03'),
#  Synset('car.n.04'),
#  Synset('cable_car.n.01')]

# %%
wn.synset('car.n.01').lemma_names()
# Out:
# ['car', 'auto', 'automobile', 'machine', 'motorcar']

# %%
wn.synset('car.n.01').lemmas()
# Out:
# [Lemma('car.n.01.car'),
#  Lemma('car.n.01.auto'),
#  Lemma('car.n.01.automobile'),
#  Lemma('car.n.01.machine'),
#  Lemma('car.n.01.motorcar')]

# %%
wn.lemmas('car')
# Out:
# [Lemma('car.n.01.car'),
#  Lemma('car.n.02.car'),
#  Lemma('car.n.03.car'),
#  Lemma('car.n.04.car'),
#  Lemma('cable_car.n.01.car')]

# %%
wn.synset('car.n.01').definition()
# Out:
# 'a motor vehicle with four wheels; usually propelled by an internal combustion engine'

# %%
wn.synset('car.n.01').examples()
# Out:
# ['he needs a car to get to work']

# %%
for lemma in wn.lemmas('car'):
    print("Lemma name:{0}, Synset: {1}".format(lemma.name(), lemma.synset()))
# Out:
# Lemma name:car, Synset: Synset('car.n.01')
# Lemma name:car, Synset: Synset('car.n.02')
# Lemma name:car, Synset: Synset('car.n.03')
# Lemma name:car, Synset: Synset('car.n.04')
# Lemma name:car, Synset: Synset('cable_car.n.01')

# %%
wn.synset('car.n.02').definition()
# Out:
# 'a wheeled vehicle adapted to the rails of railroad'

# %%
wn.synset('car.n.03').definition()
# Out:
# 'the compartment that is suspended from an airship and that carries personnel and the cargo and the power plant'
